# %%
import os
import cv2
import numpy as np
import csv

# %% [markdown]
# <hr>
#
# # Helper functions

# %%
def has_two_bones(mask, min_area_femur=5000, min_area_tibia=2500):
    """
    Check if a slice contains two large connected components:
    one for femur and one for tibia.
    """
    # Find contours
    cnts, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Compute contour areas
    areas = sorted([cv2.contourArea(c) for c in cnts], reverse=True)

    if len(areas) < 2:
        return False

    # Largest area ~ femur, second largest ~ tibia
    femur_area = areas[0]
    tibia_area = areas[1]

    return (femur_area > min_area_femur) and (tibia_area > min_area_tibia)

# %%
def find_valid_slice_range_for_case(case_files, preds_dir):
    """
    case_files: list of (slice_num, filename) for one case
    preds_dir: path to 'preds' folder
    Returns: (start_slice, end_slice, valid_slices_list)
    """
    valid_slices = []

    # Sort by slice number
    case_files = sorted(case_files, key=lambda x: x[0])

    for slice_num, fname in case_files:
        path = os.path.join(preds_dir, fname)

        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            # Skip unreadable files
            continue

        # Threshold → binary mask
        _, mask = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

        if has_two_bones(mask):
            valid_slices.append(slice_num)

    if len(valid_slices) == 0:
        return None, None, []

    return min(valid_slices), max(valid_slices), valid_slices

# %% [markdown]
# <hr>
#
# # Handle folder, files, file names

# %%
def parse_filename(filename):
    """
    Expected filename format: <case_id>_<slice>_pred.jpg
    Example: 9002116_027_pred.jpg
    Returns:
        case_id (str), slice_num (int)
    """
    # Remove extension
    name = os.path.splitext(filename)[0]       # "9002116_027_pred"
    parts = name.split('_')                    # ["9002116", "027", "pred"]

    case_id = parts[0]
    slice_num = int(parts[1])                  # "027" -> 27

    return case_id, slice_num

# %%
def process_all_cases(preds_dir="preds", output_csv="valid_slice_ranges.csv"):
    # 1) Group files by case_id
    cases = {}   # case_id -> list of (slice_num, filename)

    for fname in os.listdir(preds_dir):
        if not fname.lower().endswith((".jpg", ".png", ".jpeg", ".bmp", ".tif", ".tiff")):
            continue

        try:
            case_id, slice_num = parse_filename(fname)
        except Exception as e:
            print(f"Skipping file (cannot parse): {fname}")
            continue

        if case_id not in cases:
            cases[case_id] = []
        cases[case_id].append((slice_num, fname))

    print(f"Found {len(cases)} cases in folder '{preds_dir}'")

    # 2) For each case, find valid slice range
    results = []  # list of dicts

    for case_id, file_list in sorted(cases.items()):
        start_slice, end_slice, valid_slices = find_valid_slice_range_for_case(file_list, preds_dir)

        if start_slice is None:
            print(f"[{case_id}] No valid slices found.")
            results.append({
                "case_id": case_id,
                "start_slice": "",
                "end_slice": "",
                "num_valid_slices": 0
            })
        else:
            print(f"[{case_id}] valid slices: {start_slice} to {end_slice} "
                  f"({len(valid_slices)} slices)")
            results.append({
                "case_id": case_id,
                "start_slice": start_slice,
                "end_slice": end_slice,
                "num_valid_slices": len(valid_slices)
            })

    # 3) Save results to CSV
    with open(output_csv, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=["case_id", "start_slice", "end_slice", "num_valid_slices"])
        writer.writeheader()
        for row in results:
            writer.writerow(row)

    print(f"\nSaved results to: {output_csv}")

# %% [markdown]
# <hr>
#
# # Run and write to csv file

# %%
if __name__ == "__main__":
    process_all_cases(preds_dir="../preds", output_csv="../final_problem3_kien_steven/valid_slice_ranges.csv")
# Out:
# Found 198 cases in folder '../preds'
# [9002116] valid slices: 33 to 140 (106 slices)
# [9005075] valid slices: 30 to 136 (107 slices)
# [9005132] valid slices: 30 to 139 (107 slices)
# [9026934] valid slices: 38 to 129 (92 slices)
# [9030718] valid slices: 24 to 114 (91 slices)
# [9031141] valid slices: 16 to 133 (118 slices)
# [9033275] valid slices: 29 to 119 (91 slices)
# [9037952] valid slices: 18 to 138 (110 slices)
# [9043945] valid slices: 35 to 139 (105 slices)
# [9047800] valid slices: 26 to 130 (105 slices)
# [9048789] valid slices: 25 to 120 (96 slices)
# [9049007] valid slices: 34 to 136 (103 slices)
# [9058960] valid slices: 35 to 121 (87 slices)
# [9063955] valid slices: 41 to 134 (94 slices)
# [9064631] valid slices: 39 to 131 (93 slices)
# [9065272] valid slices: 26 to 130 (102 slices)
# [9072646] valid slices: 32 to 160 (112 slices)
# [9074878] valid slices: 37 to 123 (86 slices)
# [9081858] valid slices: 38 to 135 (98 slices)
# [9086868] valid slices: 45 to 123 (79 slices)
# [9088414] valid slices: 35 to 138 (104 slices)
# [9089119] valid slices: 29 to 118 (90 slices)
# [9101270] valid slices: 31 to 121 (91 slices)
# [9123404] valid slices: 29 to 121 (93 slices)
# [9126260] valid slices: 30 to 133 (104 slices)
# [9135752] valid slices: 29 to 119 (91 slices)
# [9138965] valid slices: 26 to 124 (99 slices)
# [9155861] valid slices: 8 to 131 (93 slices)
# [9157453] valid slices: 36 to 127 (92 slices)
# [9159804] valid slices: 20 to 122 (103 slices)
# [9167541] valid slices: 31 to 125 (92 slices)
# [9173013] valid slices: 43 to 139 (89 slices)
# [9188806] valid slices: 38 to 130 (73 slices)
# [9189986] valid slices: 3 to 158 (90 slices)
# [9208016] valid slices: 22 to 127 (105 slices)
# [9238970] valid slices: 22 to 143 (122 slices)
# [9253530] valid slices: 31 to 127 (97 slices)
# [9270239] valid slices: 34 to 134 (101 slices)
# [9273764] valid slices: 25 to 135 (111 slices)
# [9282257] valid slices: 21 to 135 (115 slices)
# [9291078] valid slices: 15 to 139 (124 slices)
# [9294761] valid slices: 38 to 126 (87 slices)
# [9300338] valid slices: 26 to 136 (109 slices)
# [9310416] valid slices: 45 to 129 (85 slices)
# [9326657] valid slices: 38 to 123 (86 slices)
# [9328093] valid slices: 32 to 119 (88 slices)
# [9330729] valid slices: 24 to 124 (92 slices)
# [9341240] valid slices: 19 to 128 (110 slices)
# [9369225] valid slices: 41 to 130 (90 slices)
# [9372474] valid slices: 34 to 123 (90 slices)
# [9373191] valid slices: 34 to 140 (100 slices)
# [9374235] valid slices: 17 to 122 (106 slices)
# [9386206] valid slices: 34 to 124 (91 slices)
# [9393987] valid slices: 30 to 126 (52 slices)
# [9402139] valid slices: 23 to 131 (106 slices)
# [9406962] valid slices: 28 to 155 (109 slices)
# [9410253] valid slices: 29 to 121 (93 slices)
# [9414291] valid slices: 39 to 136 (93 slices)
# [9414391] valid slices: 31 to 132 (99 slices)
# [9427858] valid slices: 36 to 124 (89 slices)
# [9430102] valid slices: 45 to 131 (86 slices)
# [9437407] valid slices: 30 to 135 (106 slices)
# [9438742] valid slices: 33 to 128 (96 slices)
# [9438852] valid slices: 25 to 139 (115 slices)
# [9441420] valid slices: 55 to 135 (81 slices)
# [9448098] valid slices: 4 to 118 (80 slices)
# [9452100] valid slices: 26 to 139 (114 slices)
# [9458093] valid slices: 21 to 160 (101 slices)
# [9458176] valid slices: 23 to 140 (118 slices)
# [9461404] valid slices: 29 to 123 (95 slices)
# [9467278] valid slices: 33 to 120 (88 slices)
# [9467311] valid slices: 18 to 133 (116 slices)
# [9469520] valid slices: 17 to 131 (115 slices)
# [9472254] valid slices: 28 to 120 (93 slices)
# [9475264] valid slices: 43 to 132 (85 slices)
# [9488441] valid slices: 44 to 124 (81 slices)
# [9493073] valid slices: 37 to 160 (94 slices)
# [9493245] valid slices: 16 to 135 (109 slices)
# [9493338] valid slices: 38 to 131 (94 slices)
# [9494867] valid slices: 25 to 137 (110 slices)
# [9495437] valid slices: 28 to 109 (78 slices)
# [9495873] valid slices: 26 to 132 (94 slices)
# [9497375] valid slices: 27 to 130 (104 slices)
# [9501362] valid slices: 34 to 125 (92 slices)
# [9504862] valid slices: 27 to 124 (64 slices)
# [9511423] valid slices: 28 to 136 (109 slices)
# [9512864] valid slices: 19 to 139 (103 slices)
# [9513860] valid slices: 33 to 137 (92 slices)
# [9530445] valid slices: 39 to 131 (92 slices)
# [9532970] valid slices: 34 to 114 (81 slices)
# [9542088] valid slices: 29 to 111 (83 slices)
# [9556110] valid slices: 41 to 154 (99 slices)
# [9556402] valid slices: 23 to 122 (100 slices)
# [9559547] valid slices: 50 to 126 (77 slices)
# [9559860] valid slices: 29 to 131 (103 slices)
# [9560702] valid slices: 43 to 132 (90 slices)
# [9564729] valid slices: 45 to 129 (85 slices)
# [9566972] valid slices: 27 to 110 (77 slices)
# [9568504] valid slices: 40 to 135 (96 slices)
# [9568974] valid slices: 27 to 130 (101 slices)
# [9570949] valid slices: 30 to 146 (117 slices)
# [9579246] valid slices: 27 to 125 (97 slices)
# [9581915] valid slices: 17 to 135 (115 slices)
# [9584990] valid slices: 36 to 131 (96 slices)
# [9585931] valid slices: 20 to 138 (119 slices)
# [9587941] valid slices: 24 to 136 (113 slices)
# [9596238] valid slices: 21 to 114 (94 slices)
# [9597241] valid slices: 35 to 136 (83 slices)
# [9598235] valid slices: 22 to 135 (114 slices)
# [9598683] valid slices: 23 to 132 (110 slices)
# [9601011] valid slices: 23 to 134 (112 slices)
# [9627716] valid slices: 27 to 132 (106 slices)
# [9628393] valid slices: 32 to 136 (105 slices)
# [9633944] valid slices: 41 to 128 (88 slices)
# [9634187] valid slices: 33 to 134 (102 slices)
# [9634422] valid slices: 34 to 140 (107 slices)
# [9635177] valid slices: 31 to 136 (106 slices)
# [9637676] valid slices: 24 to 132 (109 slices)
# [9638953] valid slices: 26 to 119 (94 slices)
# [9639088] valid slices: 38 to 122 (85 slices)
# [9640119] valid slices: 16 to 116 (78 slices)
# [9644109] valid slices: 33 to 122 (87 slices)
# [9645478] valid slices: 35 to 104 (70 slices)
# [9646223] valid slices: 36 to 140 (105 slices)
# [9651214] valid slices: 28 to 117 (90 slices)
# [9658152] valid slices: 22 to 110 (89 slices)
# [9680112] valid slices: 30 to 115 (86 slices)
# [9690658] valid slices: 30 to 145 (94 slices)
# [9693161] valid slices: 28 to 118 (91 slices)
# [9703327] valid slices: 28 to 132 (105 slices)
# [9708289] valid slices: 27 to 144 (96 slices)
# [9711284] valid slices: 36 to 123 (86 slices)
# [9716393] valid slices: 30 to 140 (110 slices)
# [9719999] valid slices: 24 to 132 (109 slices)
# [9721540] valid slices: 59 to 132 (74 slices)
# [9726778] valid slices: 24 to 130 (101 slices)
# [9729986] valid slices: 33 to 144 (112 slices)
# [9740303] valid slices: 28 to 138 (111 slices)
# [9745458] valid slices: 24 to 110 (76 slices)
# [9746416] valid slices: 28 to 159 (109 slices)
# [9753580] valid slices: 30 to 134 (103 slices)
# [9761431] valid slices: 28 to 121 (94 slices)
# [9764454] valid slices: 41 to 129 (89 slices)
# [9770617] valid slices: 25 to 119 (95 slices)
# [9770626] valid slices: 28 to 129 (102 slices)
# [9775951] valid slices: 29 to 133 (102 slices)
# [9776018] valid slices: 47 to 129 (83 slices)
# [9780662] valid slices: 25 to 125 (88 slices)
# [9785243] valid slices: 1 to 136 (111 slices)
# [9787693] valid slices: 21 to 125 (97 slices)
# [9788608] valid slices: 30 to 155 (89 slices)
# [9792327] valid slices: 38 to 134 (97 slices)
# [9797791] valid slices: 40 to 133 (94 slices)
# [9798351] valid slices: 25 to 132 (108 slices)
# [9800677] valid slices: 23 to 141 (114 slices)
# [9800893] valid slices: 34 to 131 (98 slices)
# [9802170] valid slices: 33 to 133 (101 slices)
# [9809967] valid slices: 45 to 127 (83 slices)
# [9812168] valid slices: 40 to 135 (94 slices)
# [9813958] valid slices: 46 to 137 (92 slices)
# [9818478] valid slices: 36 to 139 (104 slices)
# [9824274] valid slices: 21 to 121 (101 slices)
# [9830316] valid slices: 24 to 132 (109 slices)
# [9832481] valid slices: 24 to 133 (110 slices)
# [9841033] valid slices: 1 to 116 (92 slices)
# [9843822] valid slices: 25 to 132 (108 slices)
# [9843845] valid slices: 22 to 120 (93 slices)
# [9847873] valid slices: 50 to 135 (86 slices)
# [9858252] valid slices: 25 to 136 (112 slices)
# [9860356] valid slices: 34 to 127 (94 slices)
# [9861699] valid slices: 3 to 123 (76 slices)
# [9865818] valid slices: 34 to 137 (104 slices)
# [9872052] valid slices: 24 to 130 (107 slices)
# [9872426] valid slices: 46 to 132 (87 slices)
# [9874238] valid slices: 33 to 120 (88 slices)
# [9876792] valid slices: 30 to 119 (90 slices)
# [9878596] valid slices: 28 to 119 (92 slices)
# [9883115] valid slices: 36 to 123 (79 slices)
# [9885702] valid slices: 28 to 119 (92 slices)
# [9886298] valid slices: 33 to 118 (86 slices)
# [9897397] valid slices: 29 to 113 (85 slices)
# [9908796] valid slices: 33 to 123 (85 slices)
# [9915977] valid slices: 61 to 141 (81 slices)
# [9917284] valid slices: 39 to 126 (74 slices)
# [9919646] valid slices: 21 to 136 (103 slices)
# [9925131] valid slices: 30 to 135 (106 slices)
# [9925760] valid slices: 19 to 131 (113 slices)
# [9928844] valid slices: 42 to 134 (93 slices)
# [9936238] valid slices: 21 to 127 (107 slices)
# [9936312] valid slices: 27 to 114 (86 slices)
# [9948322] valid slices: 28 to 134 (107 slices)
# [9950790] valid slices: 32 to 117 (83 slices)
# [9957519] valid slices: 37 to 139 (103 slices)
# [9981798] valid slices: 30 to 124 (95 slices)
# [9988421] valid slices: 31 to 116 (86 slices)
# [9990072] valid slices: 39 to 127 (89 slices)
# [9991313] valid slices: 28 to 139 (79 slices)
# [9997856] valid slices: 28 to 140 (112 slices)
#
# Saved results to: ../final_problem3_kien_steven/valid_slice_ranges.csv
